# %%
print('ok')
# Out:
# ok

# %%
'''
mongodb+srv://dhrutewa:<password>@cluster0.2cua9gu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''
# Out:
# '\nmongodb+srv://dhrutewa:<password>@cluster0.2cua9gu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0\n'

# %%
import pandas as pd
df = pd.read_csv('EasyVisa.csv')

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data = df.to_dict(orient='records')

# %%
DB_Name = "US_VISA"
collection_name = "Visa_data"
connection_url = 'mongodb+srv://dhrutewa:dhrutewa@cluster0.2cua9gu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pymongo
client = pymongo.MongoClient(connection_url)
data_base = client[DB_Name]
collection = data_base[collection_name]
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('65dbada2777dffcde16ed129'), ObjectId('65dbada2777dffcde16ed12a'), ObjectId('65dbada2777dffcde16ed12b'), ObjectId('65dbada2777dffcde16ed12c'), ObjectId('65dbada2777dffcde16ed12d'), ObjectId('65dbada2777dffcde16ed12e'), ObjectId('65dbada2777dffcde16ed12f'), ObjectId('65dbada2777dffcde16ed130'), ObjectId('65dbada2777dffcde16ed131'), ObjectId('65dbada2777dffcde16ed132'), ObjectId('65dbada2777dffcde16ed133'), ObjectId('65dbada2777dffcde16ed134'), ObjectId('65dbada2777dffcde16ed135'), ObjectId('65dbada2777dffcde16ed136'), ObjectId('65dbada2777dffcde16ed137'), ObjectId('65dbada2777dffcde16ed138'), ObjectId('65dbada2777dffcde16ed139'), ObjectId('65dbada2777dffcde16ed13a'), ObjectId('65dbada2777dffcde16ed13b'), ObjectId('65dbada2777dffcde16ed13c'), ObjectId('65dbada2777dffcde16ed13d'), ObjectId('65dbada2777dffcde16ed13e'), ObjectId('65dbada2777dffcde16ed13f'), ObjectId('65dbada2777dffcde16ed140'), ObjectId('65dbada2777dffcde16ed141'), ObjectId('65dbada2777dffcde16e
# ...

# %%
records = collection.find()
records

# %%
df = pd.DataFrame(list(records))

# %%
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  65dbada2777dffcde16ed129  EZYV01      Asia           High School
# 1  65dbada2777dffcde16ed12a  EZYV02      Asia              Master's
# 2  65dbada2777dffcde16ed12b  EZYV03      Asia            Bachelor's
# 3  65dbada2777dffcde16ed12c  EZYV04      Asia            Bachelor's
# 4  65dbada2777dffcde16ed12d  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...
